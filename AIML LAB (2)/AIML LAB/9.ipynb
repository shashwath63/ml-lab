# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

def draw(tau):
    lowess = sm.nonparametric.lowess
    prediction = lowess(Y, X, frac=tau, it=0)
    plt.plot(X, Y, 'o', color='black')
    plt.plot(prediction[:, 0], prediction[:, 1], color='red')
    plt.show()

X = np.linspace(-3, 3, num=1000)
Y = np.log(np.abs(X ** 2 - 1) + 0.5)

draw(0.2)
draw(0.1)
draw(0.05)
draw(0.01)

# %%
pip install statsmodels
# Out:
#   Cell In[2], line 1
#     pip install statsmodels
#         ^
# SyntaxError: invalid syntax

# %%
pip install statsmodels

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (0.14.1)
# Requirement already satisfied: numpy<2,>=1.18 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.24.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (2.1.4)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (0.5.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\pratu\appdata\local\programs\python\python311\lib\site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

def draw(tau):
    lowess = sm.nonparametric.lowess
    prediction = lowess(Y, X, frac=tau, it=0)
    plt.plot(X, Y, 'o', color='black')
    plt.plot(prediction[:, 0], prediction[:, 1], color='red')
    plt.show()

X = np.linspace(-3, 3, num=1000)
Y = np.log(np.abs(X ** 2 - 1) + 0.5)

draw(0.2)
draw(0.1)
draw(0.05)
draw(0.01)
